# %%
from motif_finder import find_motif_in_sequence_list

# %%
accessions = ["NM_000546", "NM_007294", "NM_005228", "NM_002467", "NM_002046"]
motif = "TATAAA"

# %%
find_motif_in_sequence_list(motif, accessions, save=True)
# Out:
#            count_forward   positions_forward  count_reverse_complement  \
# NM_000546              0                  []                         2
# NM_007294              2        [3392, 6795]                         1
# NM_005228              3  [8215, 8548, 9012]                         7
# NM_002467              1              [2089]                         1
# NM_002046              0                  []                         0
#
#                       positions_reverse_complement  length  density_forward  \
# NM_000546                                 [35, 48]    2512         0.000000
# NM_007294                                    [131]    7088         0.000282
# NM_005228  [115, 124, 213, 1382, 1419, 1614, 3765]    9905         0.000303
# NM_002467                                   [1684]    3721         0.000269
# NM_002046                                       []    1285         0.000000
#
#            density_reverse_complement
# NM_000546                    0.000796
# ...
